# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/seq2point-nilm/blob/kengoh-22-sep-2025-redo-clean/23-September-2025-Rerunning-fridge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# sample_data/  seq2point-nilm/

# %%
cd seq2point-nilm/
# Out:
# /content/seq2point-nilm

# %%
pwd
# Out:
# '/content/seq2point-nilm'

# %%
# !python train_main.py --appliance_name fridge --epoch 10 --training_directory datasets/fridge_training_.csv --validation_directory datasets/fridge_validation_.csv
# Out:
# 2025-09-23 14:22:39.279047: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758637359.305641    6656 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758637359.312510    6656 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758637359.350758    6656 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
