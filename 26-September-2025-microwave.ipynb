# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/seq2point-nilm/blob/kengoh-22-sep-2025-redo-clean/26-September-2025-microwave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd seq2point-nilm/
# Out:
# /content/seq2point-nilm

# %%
pwd
# Out:
# '/content/seq2point-nilm'

# %%
# !mkdir saved_models

# %%
# !python train_main.py --appliance_name microwave --epoch 10 --training_directory datasets/microwave_training_.csv --validation_directory datasets/microwave_validation_.csv
# Out:
# 2025-09-25 17:34:46.771610: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758821686.808719    2445 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758821686.820473    2445 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758821686.849491    2445 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate_model.py --appliance microwave --test_file datasets/microwave_test_.csv --model_dir saved_models/
